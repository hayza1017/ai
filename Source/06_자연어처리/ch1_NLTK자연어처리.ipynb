# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:90% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:13pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:80px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:2px;}
table.dataframe{font-size:5xpt;} 
</style>
"""))
# Out:
# <style>
# div.container{width:90% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:13pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:80px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:2px;}
# table.dataframe{font-size:5xpt;}
# </style>

# %% [markdown]
# **<font size="6" color="orange">ch1. NLTK 자연어처리 패키지 </font>**
# ```
# 자연어처리 : 텍스트 전처리, 단어의 빈도수 측정, 문서유사도 측정, 연관분석, 딥러닝,
#             워드임베딩, 텍스트 분류, 어휘 데이터 베이스 사용, 감정분석, 분류분석
# ```
# # 1. NLTK 패키지
# - 텍스트 전처리, 단어빈도수 측정 : 토큰화(문장, 어절, 형태소 나누기), 정규표현식을 이용한 불용어처리, 어간추출
# - 품사태깅 : 단어별 품사를 식별
# ```
# pip install nltk==3.7
# ```

# %%
import nltk

# %%
# 말뭉치들 다운로드 받을 폴더(book선택후 다운로드)
# c:/nltk_data, e:/nltk_data, c:/Users/내컴퓨터이름/nltk_data
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
# 말뭉치 리스트
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
emma = nltk.corpus.gutenberg.raw('austen-emma.txt')
print(emma[:100])
print(type(emma))
print('글자수 :', len(emma))
# Out:
# [Emma by Jane Austen 1816]
#
# VOLUME I
#
# CHAPTER I
#
#
# Emma Woodhouse, handsome, clever, and rich, with a
# <class 'str'>
# 글자수 : 887071

# %%
# sent_tokenize() 문장 단위로 쪼갠 list 반환
from nltk.tokenize import sent_tokenize
sent_tokens =sent_tokenize(emma)
print('문장수 : ', len(sent_tokens))
print('첫문장 : ', sent_tokens[0])
# Out:
# 문장수 :  7456
# 첫문장 :  [Emma by Jane Austen 1816]
#
# VOLUME I
#
# CHAPTER I
#
#
# Emma Woodhouse, handsome, clever, and rich, with a comfortable home
# and happy disposition, seemed to unite some of the best blessings
# of existence; and had lived nearly twenty-one years in the world
# with very little to distress or vex her.

# %%
# word_tokenize() : 단어 단위로 쪼갠 list 반환
from nltk.tokenize import word_tokenize
print(word_tokenize(sent_tokens[0]))
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', 'VOLUME', 'I', 'CHAPTER', 'I', 'Emma', 'Woodhouse', ',', 'handsome', ',', 'clever', ',', 'and', 'rich', ',', 'with', 'a', 'comfortable', 'home', 'and', 'happy', 'disposition', ',', 'seemed', 'to', 'unite', 'some', 'of', 'the', 'best', 'blessings', 'of', 'existence', ';', 'and', 'had', 'lived', 'nearly', 'twenty-one', 'years', 'in', 'the', 'world', 'with', 'very', 'little', 'to', 'distress', 'or', 'vex', 'her', '.']

# %%
# RegexpTokenizer 클래스 : 정규표현식을 이용한 토큰화 작업을 하기 위함.
from nltk.tokenize import RegexpTokenizer
ret = RegexpTokenizer('\d+') # [0-9] +
digits = ret.tokenize(emma)
print(digits)
ret1 = RegexpTokenizer('\w+') #[a-zA-Z0-9]+ 
words = ret1.tokenize(sent_tokens[0])
print(words)
ret2 = RegexpTokenizer('[a-zA-Z]+') # 해당 정규표현식에 맞는 단어만 추출
words2 = ret2.tokenize(sent_tokens[0])
print(words2)
# Out:
# ['1816', '8', '23', '28', '28', '24', '7', '10', '000', '10', '000', '26']
# ['Emma', 'by', 'Jane', 'Austen', '1816', 'VOLUME', 'I', 'CHAPTER', 'I', 'Emma', 'Woodhouse', 'handsome', 'clever', 'and', 'rich', 'with', 'a', 'comfortable', 'home', 'and', 'happy', 'disposition', 'seemed', 'to', 'unite', 'some', 'of', 'the', 'best', 'blessings', 'of', 'existence', 'and', 'had', 'lived', 'nearly', 'twenty', 'one', 'years', 'in', 'the', 'world', 'with', 'very', 'little', 'to', 'distress', 'or', 'vex', 'her']
# ['Emma', 'by', 'Jane', 'Austen', 'VOLUME', 'I', 'CHAPTER', 'I', 'Emma', 'Woodhouse', 'handsome', 'clever', 'and', 'rich', 'with', 'a', 'comfortable', 'home', 'and', 'happy', 'disposition', 'seemed', 'to', 'unite', 'some', 'of', 'the', 'best', 'blessings', 'of', 'existence', 'and', 'had', 'lived', 'nearly', 'twenty', 'one', 'years', 'in', 'the', 'world', 'with', 'very', 'little', 'to', 'distress', 'or', 'vex', 'her']

# %% [markdown]
# # 2. 형태소(의미가 있는 가장 작은 단위) 분석
# - 자연어 처리의 기본 : 형태소 분석과 품사태깅 - 어간추출(Stemmer), 품사태깅(pos-tag)

# %%
words = ['sending', 'cooking', 'files', 'lives', 'crying', 'dying']
# 어간 추출1 : PorterStemmer
from nltk.stem import PorterStemmer, LancasterStemmer, RegexpStemmer
pst = PorterStemmer()
[pst.stem(word) for word in words]
# Out:
# ['send', 'cook', 'file', 'live', 'cri', 'die']

# %%
# 어간 추출2 : LancasterStemmer
lst = LancasterStemmer()
[lst.stem(word) for word in words]
# Out:
# ['send', 'cook', 'fil', 'liv', 'cry', 'dying']

# %%
# 어간 추출3 : RegexpStemmer
rst = RegexpStemmer('ing')
[rst.stem(word) for word in words]
# Out:
# ['send', 'cook', 'files', 'lives', 'cry', 'dy']

# %% [markdown]
# # 3. 품사태깅
# - https://dbrang.tistory.com/1139

# %%
from nltk.tag import pos_tag
tagged_list = pos_tag(word_tokenize(sent_tokens[0]))
print('품사태깅 결과 :', tagged_list)
# Out:
# 품사태깅 결과 : [('[', 'NNS'), ('Emma', 'NNP'), ('by', 'IN'), ('Jane', 'NNP'), ('Austen', 'NNP'), ('1816', 'CD'), (']', 'NNP'), ('VOLUME', 'NNP'), ('I', 'PRP'), ('CHAPTER', 'VBP'), ('I', 'PRP'), ('Emma', 'NNP'), ('Woodhouse', 'NNP'), (',', ','), ('handsome', 'NN'), (',', ','), ('clever', 'NN'), (',', ','), ('and', 'CC'), ('rich', 'JJ'), (',', ','), ('with', 'IN'), ('a', 'DT'), ('comfortable', 'JJ'), ('home', 'NN'), ('and', 'CC'), ('happy', 'JJ'), ('disposition', 'NN'), (',', ','), ('seemed', 'VBD'), ('to', 'TO'), ('unite', 'VB'), ('some', 'DT'), ('of', 'IN'), ('the', 'DT'), ('best', 'JJS'), ('blessings', 'NNS'), ('of', 'IN'), ('existence', 'NN'), (';', ':'), ('and', 'CC'), ('had', 'VBD'), ('lived', 'VBN'), ('nearly', 'RB'), ('twenty-one', 'CD'), ('years', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('with', 'IN'), ('very', 'RB'), ('little', 'JJ'), ('to', 'TO'), ('distress', 'VB'), ('or', 'CC'), ('vex', 'VB'), ('her', 'PRP'), ('.', '.')]

# %%
# 명사만 추출 : NN, NNS, NNPS
nouns_list = []
for word, tag in tagged_list :
    #if (tag=='NN') | (tag=='NNS') | (tag=='NNP') | (tag=='NNPS'):
    if tag in ['NN', 'NNS', 'NNP', 'NNPS']:
    #if tag.find('NN')!=-1:
        nouns_list.append(word)
print(nouns_list)
# Out:
# ['[', 'Emma', 'Jane', 'Austen', ']', 'VOLUME', 'Emma', 'Woodhouse', 'handsome', 'clever', 'home', 'disposition', 'blessings', 'existence', 'years', 'world']

# %%
nouns_list = [word for word, tag in tagged_list if tag in ['NN', 'NNS', 'NNP', 'NNPS']]
print(nouns_list)
# Out:
# ['[', 'Emma', 'Jane', 'Austen', ']', 'VOLUME', 'Emma', 'Woodhouse', 'handsome', 'clever', 'home', 'disposition', 'blessings', 'existence', 'years', 'world']

# %% [markdown]
# ## Quiz. emma 소설안에서(내가 푼 문제)
# 1. 특수문자가 들어가지 않은 3글자 이상의 단어(RegespTokenizer)만 추출해서 품사태깅(pos_tag)하시오.
# 2. 'Emma', 'emma'단어가 몇번 등장했는지, 품사태깅이 어던 품사들(set)로 되어 있는지 모두 출력하시오.
# 3. 내가 원하는 품사(명사: NN, NNS, NNP, NNPS)만 뽑아 등장하는 명사의 종류 갯수 출력

# %%
# 1. 특수문자가 들어가지 않은 3글자 이상의 단어(RegespTokenizer)만 추출해서 품사태깅(pos_tag)
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.tag import pos_tag
emma = nltk.corpus.gutenberg.raw('austen-emma.txt')
ret = RegexpTokenizer('\w{3,}')
words = ret.tokenize(emma)
tagged_list = pos_tag(words)
print('글자수 :', len(emma))
print('단어 출현 수 :', len(words), len(tagged_list))
print('단어 종류 수(겹치는 단어 제외) :', len(set(words)), len(set(tagged_list)))
# 한 단어가 다른 품사로 태깅될 수도 있음
# Out:
# 글자수 : 887071
# 단어 출현 수 : 123877 123877
# 단어 종류 수(겹치는 단어 제외) : 7630 11678

# %%
tagged_list[:10]
# Out:
# [('Emma', 'NNP'),
#  ('Jane', 'NNP'),
#  ('Austen', 'NNP'),
#  ('1816', 'CD'),
#  ('VOLUME', 'NNP'),
#  ('CHAPTER', 'NNP'),
#  ('Emma', 'NNP'),
#  ('Woodhouse', 'NNP'),
#  ('handsome', 'VBD'),
#  ('clever', 'NN')]

# %%
# 2번은 이렇게 하면 안 됨
ret_emma = RegexpTokenizer('Emma')
emmas = ret_emma.tokenize(emma)
emmas_tags = pos_tag(emmas)
print(len(emmas))
print(set([tag for word, tag in emmas_tags]))
# Out:
# 865
# {'NNP'}

# %%
print(tagged_list[:10])
# Out:
# [('Emma', 'NNP'), ('Jane', 'NNP'), ('Austen', 'NNP'), ('1816', 'CD'), ('VOLUME', 'NNP'), ('CHAPTER', 'NNP'), ('Emma', 'NNP'), ('Woodhouse', 'NNP'), ('handsome', 'VBD'), ('clever', 'NN')]

# %%
# 2. 'Emma' 단어가 몇번 등장했는지, 품사태깅이 어떤 품사들(NNP, NN, JJ, ...)로 되어 있는지 모두 출력하시오.
tags = [] # 품사들 저장할 list
for word, tag in tagged_list:
    if word == 'Emma':
        tags.append(tag)
cnt = len(tags)
pos = set(tags)
print('Emma 등장 횟수 :', cnt)
print('분류된 품사들 :', pos)
# Out:
# Emma 등장 횟수 : 865
# 분류된 품사들 : {'NN', 'NNPS', 'VBP', 'RB', 'VBD', 'NNP', 'VBN', 'NNS', 'JJ', 'VB'}

# %%
# 2. 'Emma' 단어가 몇번 등장했는지, 품사태깅이 어떤 품사들(NNP, NN, JJ, ...)로 되어 있는지 모두 출력하시오.
tags = [tag for word, tag in tagged_list if word=='Emma']
cnt = len(tags)
pos = set(tags)
print('Emma 등장 횟수 :', cnt)
print('분류된 품사들 :', pos)
# Out:
# Emma 등장 횟수 : 865
# 분류된 품사들 : {'NN', 'NNPS', 'VBP', 'RB', 'VBD', 'NNP', 'VBN', 'NNS', 'JJ', 'VB'}

# %%
# Emma를 NNP는 몇번 태깅되었는지, NNS는 몇번 태깅되었는지 등 각 품사별 태깅이 몇번 되었는지(Series이용)
import pandas as pd
pos_cnt = pd.Series([0]*len(pos), index=pos)
for word, tag in tagged_list:
    if word == 'Emma':
        pos_cnt[tag] += 1
# pos_cnt['NNP'] += 1
# pos_cnt['NN'] += 1
# pos_cnt['NNP'] += 1
pos_cnt
# Out:
# NN        7
# NNPS      2
# VBP       4
# RB        1
# VBD       1
# NNP     838
# VBN       1
# NNS       2
# JJ        4
# VB        5
# dtype: int64

# %%
# Emma를 NNP는 몇번 태깅되었는지, NNS는 몇번 태깅되었는지 등 각 품사별 태깅이 몇번 되었는지(dict이용)
pos_cnt = dict()
for word, tag in tagged_list:
    if word == 'Emma':
        if tag in pos_cnt:
            pos_cnt[tag] += 1
        else:
            pos_cnt[tag] = 1
# pos_cnt['NNP'] = 1
# pos_cnt['NN'] = 1
# pos_cnt['NNP'] += 1
print(pos_cnt)
# Out:
# {'NNP': 838, 'VBP': 4, 'JJ': 4, 'VB': 5, 'NNS': 2, 'RB': 1, 'NN': 7, 'NNPS': 2, 'VBN': 1, 'VBD': 1}

# %%
# pos_cnt.items()
sorted(pos_cnt.items(), key=lambda x:x[1], reverse=True)
# Out:
# [('NNP', 838),
#  ('NN', 7),
#  ('VB', 5),
#  ('VBP', 4),
#  ('JJ', 4),
#  ('NNS', 2),
#  ('NNPS', 2),
#  ('RB', 1),
#  ('VBN', 1),
#  ('VBD', 1)]

# %%
# 3. 명사들만 추출해서 갯수
nouns_list = []
noun_tags = ["NN", "NNS", "NNP", "NNPS"]
for word, tag in tagged_list:
    if tag in noun_tags:
        nouns_list.append(word)
nouns_list = [word for word, tag in tagged_list if tag in noun_tags]
print('명사가 나온 횟수 :', len(nouns_list))
print('출현한 명사 수(반복제거) : ', len(set(nouns_list)))
print('한단어가 나오는 평균빈도수 :',
     len(nouns_list) / len(set(nouns_list)))
# Out:
# 명사가 나온 횟수 : 30781
# 출현한 명사 수(반복제거) :  4165
# 한단어가 나오는 평균빈도수 : 7.3903961584633855

# %% [markdown]
# # 4. 최빈 단어 시각화

# %%
print(nouns_list[:10])
# Out:
# ['Emma', 'Jane', 'Austen', 'VOLUME', 'CHAPTER', 'Emma', 'Woodhouse', 'clever', 'home', 'disposition']

# %%
import matplotlib.pyplot as plt
from nltk import Text
# Text : 단어리스트와 관련된 빈도분석이나 단어검색을 쉽게 처리 할 수 있는 클래스
emma_text = Text(nouns_list)
plt.figure(figsize=(18,4))
emma_text.plot(20)
plt.show()

# %%
freqDist = emma_text.vocab()
# print(freqDist)
most_common = freqDist.most_common(20) # 상위 20개
most_common
xlabel = [word for word, count in most_common]
yvalue = [count for word, count in most_common]
plt.figure(figsize=(18,4))
plt.plot(xlabel, yvalue, marker=None)
# plt.xticks(rotation=45) # 기울기
plt.xlabel('Samples')
plt.ylabel('Counts')
# plt.grid(color='red')
plt.tight_layout()
plt.show()

# %%
emma_text.count('Emma')
# Out:
# 849

# %%
# Emma, Harriet, Jane, Frank emma소설 전체에서 어디에 등장하는지
plt.figure(figsize=(20,4))
emma_text.dispersion_plot(['Emma', 'Harriet', 'Jane', 'Frank'])

# %%
from nltk import FreqDist
tags = ['NNP', 'NNPS']
name_list = [word for word, tag in tagged_list if tag in tags]
name_count = FreqDist(name_list)
name_count
# Out:
# FreqDist({'Emma': 840, 'Mrs': 696, 'Miss': 569, 'Harriet': 484, 'Weston': 433, 'Knightley': 389, 'Elton': 382, 'Jane': 295, 'Woodhouse': 293, 'Fairfax': 241, ...})

# %%
for name, count in name_count.items():
    if count>150:
        print(name, ':', count)
# Out:
# Emma : 840
# Jane : 295
# Woodhouse : 293
# Miss : 569
# Weston : 433
# Mrs : 696
# Hartfield : 155
# Knightley : 389
# Elton : 382
# Churchill : 221
# Frank : 208
# Harriet : 484
# Fairfax : 241

# %%
name_count_s = pd.Series(name_count)
name_count_s.sort_values(ascending=False)
name_count_s[name_count_s>150]
# Out:
# Emma         840
# Jane         295
# Woodhouse    293
# Miss         569
# Weston       433
# Mrs          696
# Hartfield    155
# Knightley    389
# Elton        382
# Churchill    221
# Frank        208
# Harriet      484
# Fairfax      241
# dtype: int64

# %% [markdown]
# ## Quiz. emma 소설안에서(내가 푼 문제)
# 1. 특수문자가 들어가지 않은 3글자 이상의 단어(RegespTokenizer)만 추출해서 품사태깅(pos_tag)하시오.

# %%
ret3 = RegexpTokenizer('\w{3,}') # 해당 정규표현식에 맞는 단어만 추출
words3 = ret3.tokenize(sent_tokens[0])
pos_tag(words3)
print(words3)
# Out:
# ['Emma', 'Jane', 'Austen', '1816', 'VOLUME', 'CHAPTER', 'Emma', 'Woodhouse', 'handsome', 'clever', 'and', 'rich', 'with', 'comfortable', 'home', 'and', 'happy', 'disposition', 'seemed', 'unite', 'some', 'the', 'best', 'blessings', 'existence', 'and', 'had', 'lived', 'nearly', 'twenty', 'one', 'years', 'the', 'world', 'with', 'very', 'little', 'distress', 'vex', 'her']

# %% [markdown]
# 2. 'Emma', 'emma'단어가 몇번 등장했는지, 품사태깅이 어던 품사들(set)로 되어 있는지 모두 출력하시오.

# %%
words = ['Emma', 'emma']
pst = PorterStemmer()
[pst.stem(word) for word in words]
# Out:
# ['emma', 'emma']

# %%
lst = LancasterStemmer()
[lst.stem(word) for word in words]
# Out:
# ['emm', 'emm']

# %%
rst = RegexpStemmer('ing')
[rst.stem(word) for word in words]
# Out:
# ['Emma', 'emma']

# %% [markdown]
# 3. 내가 원하는 품사(명사: NN, NNS, NNP, NNPS)만 뽑아 등장하는 명사의 종류 갯수 출력

# %%
nouns_list = [word for word, tag in tagged_list if tag in ['NN', 'NNS', 'NNP', 'NNPS']]
print(nouns_list)
print('명사 수 : ', len(nouns_list))
# Out:
# ['[', 'Emma', 'Jane', 'Austen', ']', 'VOLUME', 'Emma', 'Woodhouse', 'handsome', 'clever', 'home', 'disposition', 'blessings', 'existence', 'years', 'world']
# 명사 수 :  16
