# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:90% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:13pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:80px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:2px;}
table.dataframe{font-size:5xpt;} 
</style>
"""))
# Out:
# <style>
# div.container{width:90% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:13pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:80px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:2px;}
# table.dataframe{font-size:5xpt;}
# </style>

# %% [markdown]
# **<font size="6" color="orange">ch3_ 연관분석</font>**
# - pip install apyori
#
# # 1. 연관분석 개요
# - 데이터들 사이의 자주 발생하는 속성을 찾고, 그 속성들 사이의 연관성이 어느 정도 있는지를 분석
# - 활용분야 : 상품진열, 사기보험적발, 신상품 카테고리 구성,...
#
# ```
# 조건(left-hand side, item_base) : 오렌지 주스(x) → 결과(right-hand side, item_add) : 와인(y)
#
# 연관분석 지표
# 1. 지지도(support) : 전체 데이터 중, 조건과 결과 항목들이 포함된 거래 비율(함께 얼마나 자주 나타나는지)
#     (x, y)의 항목 수 / 전체 데이터 수 = 0.2
# 2. 신뢰도(confidence) : 조건(x)이 발생했을 때, 결과가 동시에 일어날 확률(조건이 오면 얼마나 자주 결과가 오는지)
#     (x → y)의 항목 수 / x가 나오는 항목 수 = 0.5
# 3. 향상도(fit) : 우연히 발생할 규칙은 아니였는지 확인
#     1미만 : 독립적으로 나오는 것보다 함께 나타날 가능성이 낮다.
#     1    : 서로 독립적. 아무 연관성 없다.
#     1초과 : 양의 상관관계(같이 잘 나온다)
#     (x → y)의 지지도 / (x의 지지도 *y의 지지도) = 0.2 / (0.4*0.6) = 0.2/0.24 = 0.83333
# ```
#
# # 2. 연관분석 구현

# %%
import csv
with open('data/cf_basket.csv', encoding='utf-8') as f:
    csvdata = csv.reader(f)
    transaction = list(csvdata)
transaction
# Out:
# [['소주', '콜라', '와인'],
#  ['소주', '오렌지주스', '콜라'],
#  ['맥주', '콜라', '와인'],
#  ['소주', '콜라', '맥주'],
#  ['오렌지주스', '와인']]

# %%
from apyori import apriori
rules = apriori(transaction,
               min_support=0.15,
               min_confidence=0.1,
               min_lift=1.001)
rules = list(rules)
len(rules)
# Out:
# 6

# %%
rule = rules[5]
rule
# Out:
# RelationRecord(items=frozenset({'소주', '와인', '콜라'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'콜라'}), items_add=frozenset({'소주', '와인'}), confidence=0.25, lift=1.25), OrderedStatistic(items_base=frozenset({'소주', '와인'}), items_add=frozenset({'콜라'}), confidence=1.0, lift=1.25)])

# %%
support = rule[1]
ordered_st = rule[2]
for item in ordered_st:
    lhs = item[0]
    lhs = ','.join([x for x in lhs])
    rhs = item[1]
    rhs = ','.join([x for x in rhs])
    confidence = item[2]
    lift = item[3]
    print(f"{lhs}=>{rhs}\t {support} \t {confidence} \t {lift}")
# Out:
# 콜라=>소주,와인	 0.2 	 0.25 	 1.25
# 소주,와인=>콜라	 0.2 	 1.0 	 1.25

# %%
rules_lst = [] # 규칙을 저장할 dict list
for rule in rules:
    support = rule[1]
    ordered_st = rule[2]
    for item in ordered_st:
        lhs = item[0]
        lhs = ','.join([x for x in lhs])
        rhs = item[1]
        rhs = ','.join([x for x in rhs])
        confidence = item[2]
        lift = item[3]
        #print(f"{lhs}=>{rhs}\t {support} \t {round(confidence,2)} \t {round(lift,2)}")
#         rules_lst.append({'lhs':lhs,
#                           'rhs':rhs,
#                           'support':support,
#                           'confidence':round(confidence,2),
#                           'lift':round(lift,2)})
        rules_lst.append([lhs, rhs, support, round(confidence,2), round(lift,2)])
import pandas as pd
pd.DataFrame(rules_lst, columns=['lhs', 'rhs', 'support', 'confidence', 'lift'])
# Out:
#          lhs       rhs  support  confidence  lift
# 0         맥주        콜라      0.4        1.00  1.25
# 1         콜라        맥주      0.4        0.50  1.25
# 2         소주        콜라      0.6        1.00  1.25
# 3         콜라        소주      0.6        0.75  1.25
# 4         콜라     소주,맥주      0.2        0.25  1.25
# 5      소주,맥주        콜라      0.2        1.00  1.25
# 6         맥주     와인,콜라      0.2        0.50  1.25
# 7         콜라     와인,맥주      0.2        0.25  1.25
# 8      와인,맥주        콜라      0.2        1.00  1.25
# 9      와인,콜라        맥주      0.2        0.50  1.25
# 10        소주  오렌지주스,콜라      0.2        0.33  1.67
# 11        콜라  오렌지주스,소주      0.2        0.25  1.25
# 12  오렌지주스,소주        콜라      0.2        1.00  1.25
# 13  오렌지주스,콜라        소주      0.2        1.00  1.67
# 14        콜라     소주,와인      0.2        0.25  1.25
# 15     소주,와인        콜라      0.2        1.00  1.25

# %% [markdown]
# # 3. 뉴스 연관분석
# - 경제뉴스 20개를 각가 명사만 가져와서 lis(naver API) → 연관분석
#
# ```
# [['단어1', '단어2', '단어3', ....],
#  ['단어4', '단어5', '단어6', ....],
#  ['단어2', '단어7', '단어2', ....]...]
# ```

# %%
from dotenv import load_dotenv
import os
load_dotenv() # .env의 시스템환경변수 불러오기|
# Out:
# True

# %%
import os
import requests
import json
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
client_id = os.getenv('CLIENT_ID')
client_secret = os.getenv('CLIENT_SECRET')

url = f"https://openapi.naver.com/v1/search/news.json" # JSON 결과
params = {'query':'경제', 
          'display':20, # 가져올 데이터 개수(기본 값은 10) 
          'sort':'date'} # 최신순 뉴스
headers = {
    'X-Naver-Client-Id': client_id,
    'X-Naver-Client-Secret':client_secret
}
response = requests.get(url, params=params, headers=headers)

items = response.json()['items']

# 제목(title) + ' ' + 요약(description) 텍스트만 추출하여 list
news_texts = []
for item in items :
    title = item.get('title').replace('<b>', ' ').replace('</b>', ' ')
    description = item.get('description').replace('<b>', ' ').replace('</b>', ' ')
    news_texts.append(title + ' ' + description)

print(news_texts)
# Out:
# ["용담2동주민자치회 '소비 심백(心 百)캠페인' 전개 후 골목상권 활성화를 위한 '소비 심백 캠패인'을 전개했다. 이날 참여한 회원들은 골목상권 이용 및 지역상가와 전통시장을 방문해 주민들의 적극적인 참여를 독려하고 지역 경제 활성화에 적극 노력하기로 했다.", "천안시의회  경제 산업위, 'AI 중심 도시' 도약 위한 비교견학 ［중부매일 송문용 기자］ 천안시의회  경제 산업위원회(위원장 복아영)는 인공지능(AI) 기술이 전 산업의...  경제 산업위원회는 의원 7명과 사무국 직원 4명 등 총 11명으로 방문단을 구성해, 7일부터 8일까지 1박2일 일정으로... ", '제주 풍수해·지진재해보험료 경감...도, 지원 확대 주민과  경제 적 취약계층 등의 보험 가입을 확대하기 위해 지원을 늘렸다. 풍수해·지진재해보험은 태풍... 일부  경제 적 취약계층에 대한 지원율을 높인 것이다. 일반 세입자는 기존 지방비 추가지원 대상에서 제외됐으나... ', "도봉구, 지방재정 집행 '3년 연속 우수'…행안부 장관 표창 단순히 예산을 조기에 사용하는 데 그치지 않고 지역 경제 와 민생에 영향을 미치는 현안 사업의 집행 상황을... 김동욱 도봉구청장은 &quot;이번 표창은 지역 경제  활성화와 효율적 예산 집행을 위해 전 직원들이 노력한 결과... ", "다나와, 경희대서 인텔·다나와 IT 페스티벌 개최 커넥트웨이브 | 서울=한스 경제  김종효 기자 | 다나와는 지난 3일 경희대학교 서울캠퍼스에서 '2026 하반기 인텔&amp;다나와 아카데미 페스티벌'을 성공적으로 마쳤다고 7일 밝혔다. 이번 행사는 대학생들에게 최신 IT 제품과... ", '수원 소재 경기도기숙사 수시 입사생 모집…공실 순차 충원 손경식 경기도 청년기회과장은 “경기도기숙사는 청년들이  경제 적 부담을 덜고 학업과 취업 준비에 집중할 수 있도록 안정적인 주거환경을 제공하고 있다”며 “내년 상반기 정기 선발까지 공실에 따른 수시 모집이... ', "[기고] 염홍철 위원장에게 기대가 크다 특히 그 당시 학계의 관심사였던 선진국과 후진국의 정치· 경제 발전 이론인'종속이론'을 집중 연구하여'제3세계와 종속이론'이라는 책을 저술,많은 화제를 불러 일으키며1980년대 초 대학생들이 가장 많이 읽는 책 중... ", '장병규 크래프톤 의장, 모디 총리와 인도 게임산업 협력 논의 장 의장은 &quot;인도는 게임과 기술, 혁신 전반에 걸쳐 뛰어난 인재를 갖춘 주요 시장&quot;이라며 &quot;크래프톤의 지속적인 투자는 인도에 대한 장기적인 신뢰와 인도의 디지털  경제 에 기여하겠다는 의지를 담고 있다&quot;고 말했다.... ', "대전관광공사, '관광MICE산업발전 대상'…과학도시 연계 성과 인정 이와 함께 지역 기관과 산업, 콘텐츠 간 협력을 확대해 관광객 유치와 지역 경제  활성화, 지속 가능한 관광생태계 구축에 힘써왔다. 김용원 대전관광공사 사장은 &quot;이번 수상은 지역사회와 관계기관, 임직원이 함께... ", '정기국회 문 연 김민석 “5·18,부마항쟁 전문 수록이 개헌 출발” 민생· 경제  분야에서는 3대 메가프로젝트와 부동산 공급을 강조했다. 김 대표는 메가프로젝트를 “수도권... 9일 정치 분야를 시작으로 10일 외교·통일·안보, 11일  경제 , 14일 사회·교육·문화 분야 순으로 진행된다.... ', '美·이란 선박 공격에 국제유가 상승…브렌트 96.80달러 마리스크스는 “상업용 유조선이 상호  경제 적 압박 수단으로 의도적으로 이용되고 있다”며 “군사적 대치와 상업 해운 사이에 존재했던 구분이 크게 약화됐다”고 밝혔다. 호르무즈 해협의 선박 통항량도 다시... ', "[전문] 김민석 &quot;AI 혁명 앞 '강국 의식' 가져야…세계 이끌 것&quot; 정치,  경제 , 외교, 사회, 군사, 과학기술 모든 면에서 선진 강국 수준이고, 세계적인 매력 국가이며, 대체... 나라 밖에선 정치,  경제 , 문화적 기적으로 봅니다. 노벨상 수상자 조엘 모키어(2025)와 다론 아세모글루(2024)는... ", '핵발전소 없는 세종에서 순례를 시작한 이유 지역 경제 가 무너진 곳일수록 그 점수가 올라간다면, 그것은 동의가 아니라 궁핍의 다른 이름이다. 12차...  경제 와 발전과 성장이라는 이름의 숫자는 그 지우기를 언제나 합리적인 일로 만들어 준다. 지워진 위험은... ', '김민석 “반도체 성장 전국으로”…개헌은 “국민 원하는 선까지” 주거정책 관련 여야 협의체를 만들고, 필요하면 여야 민생 경제 협의체에서 우선적으로 다루겠다는 구상도 제시했다. 개헌과 관련해서는 “현행 헌법과 법률의 절차적 정신을 지키면서 시대의 변화와 국민 요구를 반영해... ', '[기획] 메가프로젝트 전력공급 어떻게? 전 세계적으로 AI·반도체 등 첨단산업의 성장과 산업·수송·건물 등  경제 ·사회 전반의 전기화가 빠르게 진행되면서, 안정적이고  경제 적인 전력 공급능력이 국가경쟁력을 좌우하는 핵심 요소로 부상하고 있다.... ', "[전남광주 소식] 소상공인 무료 상생보험 개시·북구 '추경 예산 1조3200... 주순선 전남광주시  경제 실장은 &quot;소상공인 비중이 높은 지역 특성을 고려할 때 이번 보험이 든든한... 이번 추경은 민생  경제 와 주민 안전, 맞춤형 복지 확대에 중점을 두고 편성됐다. 주요 사업으로 지역화폐인... ", '광주시, 기업 옴부즈만 가동…현장 건의 제도개선까지 연계 경기도와 경기도 경제 과학진흥원이 운영하는 기업옴부즈만 사업의 하나로 열린 이번 간담회에는 광주시와 경기도 경제 과학진흥원 관계자, 지역 기업 대표 등이 참여했다. 상담 분야는 자금·금융, 국내외 판로·마케팅, 환경... ', '[더밸류 브리핑] 오늘의 은행 소식…신한은행·IBK기업은행·카카오뱅크 IBK기업은행 관계자는 “정책금융기관 간 협력을 바탕으로 유망기업의 성장 단계별 자금 수요에 적극 대응하겠다”라며 “앞으로도 모험자본 시장에서 선도적 역할을 수행하고 우리  경제 의 새로운 성장동력 확충을... ', 'BBQ, 멕시코시티 이어 몬테레이에 2호점 오픈…중미 사업 확대 박차 핵심  경제 권인 몬테레이까지 거점을 넓히며 현지 시장 공략을 가속화하는 모습이다. 몬테레이는 500만명이 넘는 대도시권 인구를 보유한 멕시코 북부의 대표적인 산업· 경제  중심지다. 미국 텍사스주와 인접한... ', '군산 지역인재 70명, 전국 무대서 빛났다 기념촬영./군산시 | 군산=한스 경제  이인호 기자 | 전국 규모 대회에서 뛰어난 성적을 거둔 군산지역 학생 70명(팀)이 지역인재 장학생으로 선정됐다. 군산교육발전진흥재단(공동이사장 김재준·이항근)은 지난 5일... ']

# %%
# 명사 추출(news_texts)
stopwords = {'기사', '기자'}
from konlpy.tag import Hannanum, Kkma, Komoran, Okt
from mecab import MeCab
analyzer = MeCab()
news = []
for article in news_texts:
    nouns_list = analyzer.nouns(article)
    noun_list = [word for word, tag in analyzer.pos(article) if tag in ('NNG','NNP') and # 명사
                 word not in stopwords and #불용어(stopwords) 제외
                 len(word)>1] # 두글자 이상의 단어
    news.append(noun_list)
print(news[:3])
# Out:
# [['용담', '주민', '자치회', '소비', '캠페인', '전개', '목상', '활성', '소비', '패인', '전개', '이날', '참여', '회원', '목상', '이용', '지역', '상가', '전통', '시장', '방문', '주민', '적극', '참여', '독려', '지역', '경제', '활성', '적극', '노력'], ['천안시', '의회', '경제', '산업', '중심', '도시', '도약', '비교', '견학', '중부', '송문', '천안시', '의회', '경제', '산업', '위원회', '위원장', '아영', '인공지능', '기술', '산업', '경제', '산업', '위원회', '의원', '사무국', '직원', '방문단', '구성', '일정'], ['제주', '풍수', '지진', '재해', '보험료', '경감', '지원', '확대', '주민', '경제', '취약', '계층', '보험', '가입', '확대', '지원', '풍수', '지진', '재해', '보험', '태풍', '일부', '경제', '취약', '계층', '지원', '일반', '세입자', '기존', '지방비', '추가', '지원', '대상', '제외']]

# %%
rules = apriori(news,
                min_support=0.15,
                min_confidence=0.1,
                min_lift=1.00001)
rules = list(rules)
len(rules)
# Out:
# 12

# %%
rules_lst = [] # 규칙을 저장할 dict list
for rule in rules:
    support = rule[1]
    ordered_st = rule[2]
    for item in ordered_st:
        lhs = item[0]
        lhs = ','.join([x for x in lhs])
        rhs = item[1]
        rhs = ','.join([x for x in rhs])
        confidence = item[2]
        lift = item[3]
        #print(f"{lhs}=>{rhs}\t {support} \t {round(confidence,2)} \t {round(lift,2)}")
#         rules_lst.append({'lhs':lhs,
#                           'rhs':rhs,
#                           'support':support,
#                           'confidence':round(confidence,2),
#                           'lift':round(lift,2)})
        rules_lst.append([lhs, rhs, support, round(confidence,2), round(lift,2)])
import pandas as pd
df = pd.DataFrame(rules_lst, columns=['lhs', 'rhs', 'support', 'confidence', 'lift'])

# %%
df.sort_values(by=['lift', 'confidence', 'support'], ascending=False, inplace=True)
df # 지지도는 신뢰성 체크용
# Out:
#       lhs    rhs  support  confidence  lift
# 2      시장     지역     0.15        1.00  2.22
# 4      유치     지역     0.15        1.00  2.22
# 9      활성     지역     0.15        1.00  2.22
# 14     시장  지역,경제     0.15        1.00  2.22
# 16  경제,시장     지역     0.15        1.00  2.22
# 18     유치  지역,경제     0.15        1.00  2.22
# 20  경제,유치     지역     0.15        1.00  2.22
# 27     활성  지역,경제     0.15        1.00  2.22
# 29  경제,활성     지역     0.15        1.00  2.22
# 3      지역     시장     0.15        0.33  2.22
# 5      지역     유치     0.15        0.33  2.22
# 8      지역     활성     0.15        0.33  2.22
# 15     지역  경제,시장     0.15        0.33  2.22
# 17  지역,경제     시장     0.15        0.33  2.22
# 19     지역  경제,유치     0.15        0.33  2.22
# 21  지역,경제     유치     0.15        0.33  2.22
# 26     지역  경제,활성     0.15        0.33  2.22
# 28  지역,경제     활성     0.15        0.33  2.22
# 0      기업     지역     0.15        0.75  1.67
# 10     기업  지역,경제     0.15        0.75  1.67
# 12  경제,기업     지역     0.15        0.75  1.67
# 1      지역     기업     0.15        0.33  1.67
# 11     지역  경제,기업     0.15        0.33  1.67
# 13  지역,경제     기업     0.15        0.33  1.67
# 7      협력     지역     0.15        0.50  1.11
# 23     협력  지역,경제     0.15        0.50  1.11
# 25  협력,경제     지역     0.15        0.50  1.11
# 6      지역     협력     0.15        0.33  1.11
# 22     지역  협력,경제     0.15        0.33  1.11
# 24  지역,경제     협력     0.15        0.33  1.11
