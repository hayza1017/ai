# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:90% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:13pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:80px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:2px;}
table.dataframe{font-size:5xpt;} 
</style>
"""))
# Out:
# <style>
# div.container{width:90% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:13pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:80px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:2px;}
# table.dataframe{font-size:5xpt;}
# </style>

# %% [markdown]
# **<font size="6" color="orange">ch6_RNN기반의 Seq2Seq(스마트번역기)</font>**
#
# - Google Neural Machine Translation(GNMT)
# - RNN기반의 Seq2Seq방식
# - 인코더입력/디코더입력(모범답안) - 디코더 출력(답안) ; 인코더와 디코더가 연결된 구조

# %% [markdown]
# #  1. 패키지 import 및 하이퍼 파라미터

# %%
import numpy as np
import pandas as pd
from time import time

from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical

# 하이퍼 파라미터
MY_HIDDEN = 128
MY_EPOCH = 500

# %% [markdown]
# # 2. 학습 데이터

# %%
raw = pd.read_csv('data/translate.csv', header=None)
eng_kor = raw.values.tolist() # 데이터프레임을 list로 변환
print(eng_kor[:3])
print('학습할 영-한 데이터 갯수 :', len(eng_kor))
# Out:
# [['cold', '감기'], ['come', '오다'], ['cook', '요리']]
# 학습할 영-한 데이터 갯수 : 110

# %%
e_alpha = [c for c in 'SEPabcdefghijklmnopqrstuvwxyz']
korean = ''.join([data[1] for data in eng_kor])
print(set([ch for ch in korean]))
# Out:
# {'리', '회', '거', '한', '제', '부', '분', '많', '싸', '노', '굴', '휴', '시', '연', '쪽', '수', '날', '손', '의', '유', '용', '금', '물', '뉴', '류', '소', '아', '좋', '머', '뿌', '주', '놀', '익', '움', '생', '합', '방', '스', '광', '들', '위', '색', '미', '녀', '비', '먼', '농', '람', '통', '획', '계', '무', '기', '목', '실', '각', '쉽', '은', '멍', '파', '망', '랑', '번', '개', '내', '높', '키', '음', '램', '사', '얇', '명', '고', '간', '이', '험', '단', '출', '요', '팔', '구', '반', '복', '넓', '탈', '짜', '적', '깊', '감', '행', '핑', '입', '름', '그', '릎', '매', '크', '장', '식', '관', '읽', '규', '오', '칙', '선', '동', '래', '모', '책', '운', '다', '지', '약', '옥', '왼', '게', '편', '작', '메', '것', '찾', '서', '가', '우', '나', '택', '남', '인', '바', '을', '얼', '늦', '여', '흐', '상', '어', '언', '피', '도', '자', '해', '붕'}

# %% [markdown]
# # 4. 문자당 num을 갖는 dict
# - 전예제 : {'the':1, 'a':2, ..} / {1:'the', 2:'a',...}
# - {'S':0, 'E':1,...}

# %%
char_to_num ={}
for i, ch in enumerate(alpha)

# %%
# 문자 → 숫자 / 숫자 → 문자
print('문자 → 숫자 :', char_to_num.get('c'))
print('숫자 → 문자 :', alpha[5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # 문자 → 숫자 / 숫자 → 문자
# ----> 2 print('문자 → 숫자 :', char_to_num.get('c'))
#       3 print('숫자 → 문자 :', alpha[5])
#
# NameError: name 'char_to_num' is not defined
