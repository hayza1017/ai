# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:80% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:10pt;}
div.output {font-size:10pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:10pt;}
div.prompt {min-width:80px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:10pt;padding:2px;}
table.dataframe{font-size:20px;}
</style>
"""))
# Out:
# <style>
# div.container{width:80% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:10pt;}
# div.output {font-size:10pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:10pt;}
# div.prompt {min-width:80px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:10pt;padding:2px;}
# table.dataframe{font-size:20px;}
# </style>

# %% [markdown]
# <font size="6" color="green">ch06. 모듈과 패키지</font>
# # 1절. 파이썬 표준 모듈 사용
# - 모듈 : 함수, 변수, class 등을 담고 있는 파이썬 코드 파일(*.py)
# ```
# 파이썬 설치하는 방법
#     - pythone.org / microsoft store : 파이썬 표준 모듈 200여개가 포함된 파이썬 인터프린터를 install
#                                        (sys, re, datetime, time...)
#     - miniconda : pythone.org버전보다 조금 많은 모듈이 포함된 인터프린터를 install
#     - anaconda : 몇백개 이상의 패키지, 개발도구(IDE tools;jupyter notebook)를 포함한 인터프린터 설치
#                 (200명 이상의 기업체에서는 유료)
#
#     - uv(pip-파이썬 패키지 설치도구, 패키지/프로젝트 관리도구)를 이용한 설치
#         * 참조 : https://docs.astral.sh/uv/getting-started/installation/
#             - powershell -ExecutionPolicy ByPass -c "irm https://astral.sh/uv/install.ps1 | iex(powershell관리자권한)
#         * uv설치 후 파이썬 설치
#
#         * Set-ExecutionPolicy RemoteSigned -Scope CurrentUser
#         * Get-ExecutionPolicy명령으로 RemoteSigned출력확인
#         * powershell -ExecutionPolicy ByPass -c "irm https://astral.sh/uv/install.ps1 | iex"
#         * powershell 닫았다 다시 열기
#         * uv python list
#         * uv python install 3.11(업계에서는 3.13이상은 잘 안 씀) - 지금은 하지 마셔요
# ```
# ## 1.1 파이썬 모듈

# %%
# 1. import 모듈명 : 모듈한의 함수, 클래스, 변수를 모듈명.함수명()으로 사용
import time # time모듈 안의 함수, 변수, 클래스를 메모리 로드
time.ctime() # 현재 날짜와 시간을 return
# Out:
# 'Mon Jul  6 10:50:48 2026'

# %%
time.time() # 1970.1.1부터 초
# Out:
# 1783303038.202145

# %%
# %%time
import time
start = time.time()
cnt = 0
while cnt<=10000000:
    cnt += 1
end = time.time()
print('반복문 1천만번 돈 시간 :', (end-start), '초')
# Out:
# 반복문 1천만번 돈 시간 : 1.8208494186401367 초
# CPU times: total: 1.66 s
# Wall time: 1.82 s

# %%
del time # time 모듈을 메모리에서 unlood

# %%
# 2. from 모듈(A) import 함수|클래스|변수(B)  - A모듈 안의 B만 로드
#    form 패키지(A) import 모듈(B)           -A패키지 안의 B모듈을 로드
#    form 패키지(A).모듈명(B)import함수명(B)  -A 패키지 안의 B모듈의 B함수만 로드
#     from time import ctime
#     from time import time
from time import ctime, time
ctime()
# Out:
# 'Mon Jul  6 11:08:00 2026'

# %%
time()
# Out:
# 1783303687.826417

# %%
del ctime
del time

# %%
# 3. import 모듈명 as 별칭 : 모듈을 메모리에 로드하고 별칭으로 사용 import numpy as np
import time as t
t.ctime()
# Out:
# 'Mon Jul  6 11:10:25 2026'

# %%
t.time()
# Out:
# 1783303833.705934

# %%
time.time()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 time.time()
#
# NameError: name 'time' is not defined

# %%
del t

# %%
# 4. from 모듈명 import 함수명 as 별칭 : 모듈 안에 함수를 메모리에 로드하고 별칭으로 함수 사용
#    from 패키지명 import 모듈병 as 별칭 : 모듈명을 별칭으로 사용
#    from 패키지명.모듈명 import 함수명 as 별칭
from time import ctime as ct, time as ti
ct()
# Out:
# 'Mon Jul  6 11:14:14 2026'

# %%
ti()
# Out:
# 1783304059.1075542

# %%
import time
print(dir(time)) # time모듈안의 변수, 함수, 클래스명을 list로
# Out:
# ['_STRUCT_TM_ITEMS', '__doc__', '__loader__', '__name__', '__package__', '__spec__', 'altzone', 'asctime', 'ctime', 'daylight', 'get_clock_info', 'gmtime', 'localtime', 'mktime', 'monotonic', 'monotonic_ns', 'perf_counter', 'perf_counter_ns', 'process_time', 'process_time_ns', 'sleep', 'strftime', 'strptime', 'struct_time', 'thread_time', 'thread_time_ns', 'time', 'time_ns', 'timezone', 'tzname']

# %%
'''
모듈/패키지이나 모듈안의 함수를 가져오는 방법

import A                - A모듈을 가져옴
import A as B           - A모듈을 B이름으로 가져옴
from A import B         - A모듈안의 B함수(클래스|변수)를 가져옴
from A import B as C    - A모듈안의 B함수를 C이름으로 가져옴

from A import B         - A패키지 안의 B모듈을 가져옴
from A.B import C       - A패키지 안의 B모듈안의 C함수 가져옴
from A import B as C    - A패키지 안의 B모듈을 C이름으로 가져옴
from A.B import C as D  - A패키지 안의 B모듈안의 C를 D이름으로 가져옴
'''
# Out:
# '\n모듈/패키지이나 모듈안의 함수를 가져오는 방법\n\nimport A                - A모듈을 가져옴\nimport A as B           - A모듈을 B이름으로 가져옴\nfrom A import B         - A모듈안의 B함수(클래스|변수)를 가져옴\nfrom A import B as C    - A모듈안의 B함수를 C이름으로 가져옴\n\nfrom A import B         - A패키지 안의 B모듈을 가져옴\nfrom A.B import C       - A패키지 안의 B모듈안의 C함수 가져옴\nfrom A import B as C    - A패키지 안의 B모듈을 C이름으로 가져옴\nfrom A.B import C as D  - A패키지 안의 B모듈안의 C를 D이름으로 가져옴\n'

# %% [markdown]
# # 2절 사용자 정의 모듈
# - 함수나 클래스나 변수 등을 파이썬 파일(*.py)에 저장해서 모듈을 만들고, 재사용할 수 있음 <- 현재 폴더 밑의 ch03.py
# - 모듈을 가져오는 순서 (1)표준모듈 (2) sys.path변수에 저장된 경로 _예외 (3) 현재 실행하는 폴더
# -

# %%
import add_operation
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 import add_operation
#
# ModuleNotFoundError: No module named 'add_operation'

# %%
import sys
sys.path
# Out:
# ['C:\\Ai\\Source\\01_python',
#  'C:\\Users\\water\\anaconda3\\python310.zip',
#  'C:\\Users\\water\\anaconda3\\DLLs',
#  'C:\\Users\\water\\anaconda3\\lib',
#  'C:\\Users\\water\\anaconda3',
#  '',
#  'C:\\Users\\water\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\water\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\water\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\water\\anaconda3\\lib\\site-packages\\Pythonwin']

# %%
r"C:\ai\Source\pylib" # == "C:\\ai\\Source\\pylib"
# Out:
# 'C:\\ai\\Source\\pylib'

# %%
sys.path.append(r"C:\ai\Source\pylib")
sys.path
# Out:
# ['C:\\Ai\\Source\\01_python',
#  'C:\\Users\\water\\anaconda3\\python310.zip',
#  'C:\\Users\\water\\anaconda3\\DLLs',
#  'C:\\Users\\water\\anaconda3\\lib',
#  'C:\\Users\\water\\anaconda3',
#  '',
#  'C:\\Users\\water\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\water\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\water\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\water\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\ai\\Source\\pylib']

# %% [markdown]
# ## 1. import 모듈명

# %%
import add_operation
add_operation.add_print(10)
# Out:
# 1부터 10까지 누적합은 55입니다.

# %%
result = add_operation.add_return(10)
result
# Out:
# 55

# %%
add_operation.PI
# Out:
# 3.141592

# %%
# !python c:/ai/source/pylib/add_operation.py
# Out:
# 기본적으로 실행시 숫자를 입력하지 않으먄 100으로
# 1. add_print1부터 100까지 누적합은 5050입니다.
# 2. add_return : 5050
# 3.141592

# %%
# !python c:/ai/source/pylib/add_operation.py 50
# Out:
# 1. add_print1부터 50까지 누적합은 1275입니다.
# 2. add_return : 1275
# 3.141592

# %% [markdown]
# ## 2. from A import B

# %%
from add_operation import add_print, add_return, PI
PI
# Out:
# 3.141592

# %%
add_print(50)
# Out:
# 1부터 50까지 누적합은 1275입니다.

# %% [markdown]
# ## 3. import A as B

# %%
import add_operation as operation
operation.add_print(20)
# Out:
# 1부터 20까지 누적합은 210입니다.

# %%
operation.PI
# Out:
# 3.141592

# %% [markdown]
# ## 4. from A import B as C

# %%
from add_operation import add_print as add_p, PI
add_p(50)
# Out:
# 1부터 50까지 누적합은 1275입니다.

# %%
PI
# Out:
# 3.141592

# %% [markdown]
# # 3절. 패키지
# ```
# - 모듈(py)들이 들어있는 폴더(__init__.py파일이 있어야)
# ```

# %%
sys.path
# Out:
# ['C:\\Ai\\Source\\01_python',
#  'C:\\Users\\water\\anaconda3\\python310.zip',
#  'C:\\Users\\water\\anaconda3\\DLLs',
#  'C:\\Users\\water\\anaconda3\\lib',
#  'C:\\Users\\water\\anaconda3',
#  '',
#  'C:\\Users\\water\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\water\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\water\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\water\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\ai\\Source\\pylib']

# %%
#  상위패키지를 import한다고 하위패키지가 import되지 않음
# 패키지를 import한다고 modul이 import되지 않음
import sample_pac # sample_pac/__init__.py를 로드
# Out:
# sample_pac 패키지를 로드 확인(__init__.py)

# %%
sample_pac.test()
# Out:
# test해 봄

# %%
sample_pac.ab.a.hello()

# %%
del sample_pac

# %%
import sample_pac.ab # ab/__init__.py가 로드 됨
# Out:
# sample_pac안의 ab패키지 로드됨

# %%
sample_pac.ab.a.hello()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 sample_pac.ab.a.hello()
#
# AttributeError: module 'sample_pac.ab' has no attribute 'a'

# %%
del sample_pac.ab

# %%
from sample_pac.ab import * # * : __all__을 로드해

# %%
a.hello()
# Out:
# sample_pac/ab/a모듈의 hello

# %%
b.world()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 b.world()
#
# NameError: name 'b' is not defined

# %%
from sample_pac.ab import b
b.world()
# Out:
# sample_pac/ab/b모듈안의 world

# %%
from sample_pac.ab.b import world
world()
# Out:
# sample_pac/ab/b모듈안의 world

# %% [markdown]
# # 4절. 패키지 설치 및 삭제
# ```
# 아나콘다 프롬프트에서
# - 패키지 설치 : pip install 패키지명 [==버전] / conda install 패키지명[==버전] / uv pip install 패키지명[==버전]
# - 패키지 확인 : pip show 패키지명            / conda list 패키지명
# - 패키지 삭제 : pip unistall 패키지명        / conda remove 패키지명
# -
# ```

# %%
import objgraph # 아나콘다 프롬프트에서 pip install objgraph

# %%
objgraph.show_most_common_types() # 메모리 사용량 출력
# Out:
# list          35468
# dict          35046
# function      18549
# Token         16848
# Operator      16354
# tuple         14211
# Name          13507
# PythonNode    11604
# ReferenceType 5556
# DFAPlan       5418

# %%
! pip uninstall objgraph -y
# Out:
# Found existing installation: objgraph 3.6.2
# Uninstalling objgraph-3.6.2:
#   Successfully uninstalled objgraph-3.6.2

# %% [markdown]
# # 5절. 연습문제

# %% [markdown]
# ## 1. 파이썬의 모듈과 패키지에 대해 잘 못 설명한 것은?
# ① 모듈은 파일 단위로 작성하면 확장자가 .py인 파이썬 파일이다. \
# ② 패키지는 모듈들의 모음이며 디렉터리 단위로 존재한다.\
# ③ 파이썬의 표준 라이브러리는 import하지 않고 사용할 수 있다. \
# ④ 일부 모듈 세트는 특정 플렛폼에서만 사용할 수 있다.

# %%
# 정답 : 3번

# %% [markdown]
# ## 2. 다음 중 모듈의 import와 import후 사용 방법이 잘 못 된 것은?
# ① import time \
#    time. ctime() \
# ② import time as t \
#    t.ctime() \
# ③ from time import ctime\
#    ctime() \
# ④ from time import ctime as ct \
#    ctime()

# %%
# 정답 : 4번

# %% [markdown]
# ## 3. 파이썬이 디렉터리를 패키지에 포함하도록 처리하기 위해 필요한 파일은?

# %%
# 정답 : __init__.py

# %% [markdown]
# ## 4. import*을 이용하면 패키지에 있는 서브 모듈을 찾아서 모두 가져옵니다. 그렇기 때문에 패키지 작성작가 패키지의 명식적 색인을 제공하기 위해 사용하는 속성의 이름은 무엇인가요?

# %%
# 정답 : __all__

# %% [markdown]
# ## 5. 다음 중 파이썬 패키지를 설치하는 방법이 아닌 것은?
# ① python -m pip install --upgrade pip \
# ② pip instal 패키지명 \
# ③ conda install 패키지명 \
# ④ pip install 휠(whl)파일경로

# %%
# 정답 : 1번
